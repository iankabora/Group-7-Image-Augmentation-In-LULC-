# %%
import cv2 
import tensorflow as tf 
CATEGORIES = {"original","rotated"}

def prepare (filepath):
    IMG_SIZE =30
    img_array =cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array= cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
    return new_array.reshape (-1, IMG_SIZE,IMG_SIZE, 1)
model = tf.keras.models.load_model("64 x 3- CNN.model")

pred = model.predict([prepare("River_1954.jpg")])




print (pred)
# Out:
# [[ 5.861372    0.          0.          0.4582007   2.9389265   0.
#    0.          0.55368876  0.         10.069868    0.          9.361654
#    0.          0.          0.          5.2771273   0.          6.662569
#    0.          0.          0.          1.9430559   0.          8.172518
#    0.          0.          1.9835482   0.          8.939598    6.633643
#    0.          3.8846436   0.          0.         14.357891    0.
#    6.7439394   5.595175    0.          6.3610353   0.          3.532972
#    0.          0.          0.          0.         13.324948    0.
#   10.40622     3.067352    0.          1.5327628   0.9223044  10.795017
#   24.59748     0.          0.          0.          5.817753    0.70909846
#    0.          0.         14.344842    6.045082    9.957111    0.
#    0.          0.9049554   2.8923147   0.          0.          0.
#    0.          7.0810103   0.         10.841293    1.438849    0.
#    0.          8.1311655   0.          7.0033693   0.          0.
# ...

# %%
import numpy as np
def acc(y_true, pred):
    return np.equal(y_true, np.round(pred)).mean()

# %%
def prepare (filepath):
    pred =cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    pred= cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))

    return new_array.reshape (-1, IMG_SIZE,IMG_SIZE, 1)

pred = np.random.random((5))

print("y_true:" + str(y_test))
print("pred: " + str(np.round(pred).astype(int)))

def acc(y_true, pred):

    print("accuracy: " + str(acc(y_test, pred)))
# Out:
# y_true:[[ 5.861372    0.          0.          0.4582007   2.9389265   0.
#    0.          0.55368876  0.         10.069868    0.          9.361654
#    0.          0.          0.          5.2771273   0.          6.662569
#    0.          0.          0.          1.9430559   0.          8.172518
#    0.          0.          1.9835482   0.          8.939598    6.633643
#    0.          3.8846436   0.          0.         14.357891    0.
#    6.7439394   5.595175    0.          6.3610353   0.          3.532972
#    0.          0.          0.          0.         13.324948    0.
#   10.40622     3.067352    0.          1.5327628   0.9223044  10.795017
#   24.59748     0.          0.          0.          5.817753    0.70909846
#    0.          0.         14.344842    6.045082    9.957111    0.
#    0.          0.9049554   2.8923147   0.          0.          0.
#    0.          7.0810103   0.         10.841293    1.438849    0.
# ...

# %%
y_test = np.array([1, 0, 0, 1, 0])
pred = np.random.random((5))

print("y_true:" + str(y_test))
print("pred: " + str(np.round(pred).astype(int)))

def acc(y_true, pred):
    return np.equal(y_true, np.round(pred)).mean()

print("accuracy: " + str(acc(y_test, pred)))
# Out:
# y_true:[1 0 0 1 0]
# pred: [1 0 1 1 1]
# accuracy: 0.6
